# %%
from Univariate import Univariate

#obj=Univariate()

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#quan,qual=obj.quanqual(dataset)

# %%
# Step 1: Separate quantitative and qualitative columns
quan, qual = Univariate.quanqual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
# Step 2: Get univariate descriptive stats
descriptive = Univariate.univariate(dataset,quan)

# %%
descriptive
# Out:
#           sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# Mean        108  67.3034  66.3332  66.3702  72.1006  62.2782  288655
# Median      108       67       65       66       71       62  265000
# Mode          1       62       63       65       60     56.7  300000
# Q1:25%     54.5     60.6     60.9       61       60   57.945  240000
# Q2:50%      108       67       65       66       71       62  265000
# Q3:75%    161.5     75.7       73       72     83.5   66.255  300000
# 99%      212.86       87    91.86    83.86       97  76.1142     NaN
# Q4:100%     215     89.4     97.7       91       98    77.89  940000
# IQR         107     15.1     12.1       11     23.5     8.31   60000
# 1.5rule   160.5    22.65    18.15     16.5    35.25   12.465   90000
# Lesser     -106    37.95    42.75     44.5    24.75    45.48  150000
# Greater     322    98.35    91.15     88.5   118.75    78.72  390000
# Min           1    40.89       37       50       50    51.21  200000
# ...

# %%
# Step 3: Find outliers
lesser, greater = Univariate.outlier_columnName(descriptive, quan)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
# Step 4: Replace outliers
df_cleaned, without_lesser, without_greater = Univariate.replacing_outlier(dataset.copy(), descriptive, lesser, greater, quan)

# %%
df_cleaned
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
without_lesser
# Out:
# ['hsc_p']

# %%
without_greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
# Step 5: Frequency table for a qualitative column
freq_table = Univariate.freqTable("some_qual_column", dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\MonicaAI\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'some_qual_column'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15856\3145598940.py in <module>
# ...

# %%
lesser
# Out:
# ['hsc_p']

# %%
# Step 2: Get univariate descriptive stats
descriptive = Univariate.univariate(dataset,quan)

# %%
descriptive
